# %%
import pandas as pd

# %%
df1 = pd.read_csv('true_news.csv')
df1 = df1.drop(['Unnamed: 0', 'long_description'], axis=1)
temp = [1]*len(df1)
df1['Label'] = temp
df1 = df1.rename(columns={'short_description': 'News', 'full_title': 'Heading'})
#df1 = df1.fillna('', inplace=True)
df1
# Out:
#                                                   News  \
# 0    पूछ जाए दिल्ल पहल गणतंत्र दिवस परेड कह इसक जवा...
# 1               वेब सिरीज़ तांडव ले जार विवाद कार्टून
# 2    बेक समझौ H1B वीज़ के नए नियम क्वॉड समूह गठन - ...
# 3    विपक्ष कांग्रेस पार्ट सरकार स्थित स्पष्ट कह दू...
# 4    बाइडन-कमल हैरिस टीम अप प्रशासन के भारतीय मूल क...
# ..                                                 ...
# 434  पाकिस्तान कभ दूसर धुर-विरोध रह विपक्ष पार्ट इम...
# 435  तेलंग आंध्र प्रदेश केरल कर्नाटक ओडिश महाराष्ट्...
# 436  बिहार के जातिगत समीकरण बात लंब बीजेप हिंद पहचा...
# 437  गुरुवार राज्य सात मही के सिनेमाघर मल्टीप्लेक्स...
# 438  भारतीय विदेश मंत्रालय के प्रवक् अनुराग श्रीवास...
#
#                                                Heading  Label
# 0                    26 जनवर गणतंत्र दिवस पहल परेड कह       1
# 1                                कार्टून सख़्त ज़रूरत       1
# 2        डोनाल्ड ट्रंप भारत मोद सरकार मुश्किल बढ़ दिय       1
# ...

# %%
df1.isnull().sum(axis = 0)
# Out:
# News       0
# Heading    0
# Label      0
# dtype: int64

# %%
df2 = pd.read_json('true_news_all_dirty.json')
df2 = df2.drop(['url', 'full_title', 'long_description'], axis=1)
temp = [1]*len(df2)
df2['Label'] = temp
df2 = df2.rename(columns={'short_desc': 'News', 'name': 'Heading'})
#df2 = df2.fillna('', inplace=True)
df2
# Out:
#                                                Heading  \
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...
# 3                   कहां हुई थी पहली गणतंत्र दिवस परेड
# 4                             कार्टून: सख़्त ज़रूरत है
# ..                                                 ...
# 888  ब्रह्मोस एक्सटेंडड रेंज सुपरसोनिक क्रूज़ मिसाइ...
# 889      भोलू पहलवानों को भारत क्यों नहीं आने दिया था?
# 890  बिहार: जातीय समीकरणों और बीजेपी के हिंदुत्व का...
# 891  स्टेन स्वामी: सबसे बुजुर्ग शख़्स जिन पर लगा आत...
# 892  चीन के साथ संघर्ष हुआ तो भारत का कितना साथ देग...
#
#                                                   News  Label
# 0    भारत ने ऑस्ट्रेलिया में टेस्ट सिरीज़ में ऐतिहा...      1
# 1    ब्रिस्बेन टेस्ट में भारत की दीवार कहे जाने वाल...      1
# 2    पाकिस्तानी टीवी प्रेजेंटर सैय्यद इक़रारुल हसन ...      1
# ...

# %%
df2.isnull().sum(axis = 0)
# Out:
# Heading    0
# News       0
# Label      0
# dtype: int64

# %%
import numpy as np
df2 = df2.replace(np.nan, '', regex=True)
df2
# Out:
#                                                Heading  \
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...
# 3                   कहां हुई थी पहली गणतंत्र दिवस परेड
# 4                             कार्टून: सख़्त ज़रूरत है
# ..                                                 ...
# 888  ब्रह्मोस एक्सटेंडड रेंज सुपरसोनिक क्रूज़ मिसाइ...
# 889      भोलू पहलवानों को भारत क्यों नहीं आने दिया था?
# 890  बिहार: जातीय समीकरणों और बीजेपी के हिंदुत्व का...
# 891  स्टेन स्वामी: सबसे बुजुर्ग शख़्स जिन पर लगा आत...
# 892  चीन के साथ संघर्ष हुआ तो भारत का कितना साथ देग...
#
#                                                   News  Label
# 0    भारत ने ऑस्ट्रेलिया में टेस्ट सिरीज़ में ऐतिहा...      1
# 1    ब्रिस्बेन टेस्ट में भारत की दीवार कहे जाने वाल...      1
# 2    पाकिस्तानी टीवी प्रेजेंटर सैय्यद इक़रारुल हसन ...      1
# ...

# %%
df = df2.append(df1)
df
# Out:
#                                                Heading  \
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...
# 3                   कहां हुई थी पहली गणतंत्र दिवस परेड
# 4                             कार्टून: सख़्त ज़रूरत है
# ..                                                 ...
# 434  पाकिस्तान इमरान ख़ान सरकार सत् हट मुहिम विपक्ष...
# 435         दक्षिण भारत भार बारिश कम-से-कम 30 लोग मौत
# 436   बिहार जातीय समीकरण बीजेप के हिंदुत्व दंगल चुनाव
# 437                   अनलॉक 5 कहाँ-कह खुल रह सिनेमाघर
# 438  पाकिस्ता एनएसए के दाव भारत कह नसीहत अप सरकार र...
#
#                                                   News  Label
# 0    भारत ने ऑस्ट्रेलिया में टेस्ट सिरीज़ में ऐतिहा...      1
# 1    ब्रिस्बेन टेस्ट में भारत की दीवार कहे जाने वाल...      1
# 2    पाकिस्तानी टीवी प्रेजेंटर सैय्यद इक़रारुल हसन ...      1
# ...

# %%
dff = pd.read_csv('real_news.csv')
df = df.append(dff)
df
# Out:
#                                                Heading  \
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...
# 3                   कहां हुई थी पहली गणतंत्र दिवस परेड
# 4                             कार्टून: सख़्त ज़रूरत है
# ..                                                 ...
# 190  मुसलमानों में सबसे ज़्यादा घटी प्रजनन दर फिर भ...
# 191  पुतिन की ‘गर्लफ़्रेंड’ अलीना कबाएवा कौन हैं, ज...
# 192  हैदराबाद: हिन्दू-मुस्लिम विवाह, दलित लड़के की ...
# 193  झारखंड की एक ख़ास प्रथा, जहां लिव-इन के बाद हो...
# 194  महाराष्ट्र का सोंडेघर गांव: दंगा रोकने के लिए ...
#
#                                                   News  Label
# 0    भारत ने ऑस्ट्रेलिया में टेस्ट सिरीज़ में ऐतिहा...      1
# 1    ब्रिस्बेन टेस्ट में भारत की दीवार कहे जाने वाल...      1
# 2    पाकिस्तानी टीवी प्रेजेंटर सैय्यद इक़रारुल हसन ...      1
# ...

# %%
df.to_csv('real_news_all.csv', index=False)

# %%
df['News'] = df['Heading'] + df['News']
df = df.drop(['Heading'], axis=1)
df
# Out:
#                                                   News  Label
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...      1
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...      1
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...      1
# 3    कहां हुई थी पहली गणतंत्र दिवस परेडकिसी से पूछा...      1
# 4    कार्टून: सख़्त ज़रूरत हैवेब सिरीज़ तांडव को ले...      1
# ..                                                 ...    ...
# 190  मुसलमानों में सबसे ज़्यादा घटी प्रजनन दर फिर भ...      1
# 191  पुतिन की ‘गर्लफ़्रेंड’ अलीना कबाएवा कौन हैं, ज...      1
# 192  हैदराबाद: हिन्दू-मुस्लिम विवाह, दलित लड़के की ...      1
# 193  झारखंड की एक ख़ास प्रथा, जहां लिव-इन के बाद हो...      1
# 194  महाराष्ट्र का सोंडेघर गांव: दंगा रोकने के लिए ...      1
#
# [1527 rows x 2 columns]

# %%
df.isnull().sum(axis = 0)
# Out:
# News     0
# Label    0
# dtype: int64

# %%
df.to_csv('real_news_all.csv', index=False)

# %%
dtf1 = pd.read_csv('true_news_basic.csv')
dtf1 = dtf1.drop(['Unnamed: 0'], axis=1)
temp = [1]*len(dtf1)
dtf1['Label'] = temp
dtf1 = dtf1.rename(columns={'short_description': 'News'})
dtf1
# Out:
#                                                   News  Label
# 0    भारत ऑस्ट्रेलिय टेस्ट सिरीज़ ऐतिहासिक जीत दर्ज...      1
# 1    ब्रिस्बेन टेस्ट भारत दीवार कह वाल चेतेश्वर पुज...      1
# 2    पाकिस्ता टीव प्रेजेंटर सैय्यद इक़रारुल हसन अप ...      1
# 3    पूछ जाए दिल्ल पहल गणतंत्र दिवस परेड कह इसक जवा...      1
# 4               वेब सिरीज़ तांडव ले जार विवाद कार्टून       1
# ..                                                 ...    ...
# 755  चालक कार रोक के बजाय चल जार रख ट्रैफ़िक पुलिसक...      1
# 756                 मिसाइल 400 किलोमीटर ज़्याद मार सक       1
# 757  आकर्षण केंद्र वो शक्तिशाल पहलवान जिनक संबंध प्...      1
# 758  बिहार के जातिगत समीकरण बात लंब बीजेप हिंद पहचा...      1
# 759  एनआईए 83 साल के फ़ादर स्टेन स्वाम गिरफ़्तार यू...      1
#
# [760 rows x 2 columns]

# %%
df = df.append(dtf1)
df
# Out:
#                                                   News  Label
# 0    मोहम्मद सिराज ने हाल में पिता को खो दिया था ले...      1
# 1    ब्रिसबेन टेस्ट का वो पल जब पुजारा के पापा डर ग...      1
# 2    पाकिस्तान के टीवी एंकर इक़रारुल हसन ने भारत की...      1
# 3    कहां हुई थी पहली गणतंत्र दिवस परेडकिसी से पूछा...      1
# 4    कार्टून: सख़्त ज़रूरत हैवेब सिरीज़ तांडव को ले...      1
# ..                                                 ...    ...
# 755  चालक कार रोक के बजाय चल जार रख ट्रैफ़िक पुलिसक...      1
# 756                 मिसाइल 400 किलोमीटर ज़्याद मार सक       1
# 757  आकर्षण केंद्र वो शक्तिशाल पहलवान जिनक संबंध प्...      1
# 758  बिहार के जातिगत समीकरण बात लंब बीजेप हिंद पहचा...      1
# 759  एनआईए 83 साल के फ़ादर स्टेन स्वाम गिरफ़्तार यू...      1
#
# [2287 rows x 2 columns]

# %%
df.to_csv('real_news_all.csv', index=False)
